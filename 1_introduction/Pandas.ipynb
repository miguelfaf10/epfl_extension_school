# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Grouping

# %%
df = pd.read_csv("c1_songs_requested.csv")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 df = pd.read_csv("c1_songs_requested.csv")                                                   │
# │ ❱ 2 df.sum(axis=1)                                                                               │
# │   3                                                                                              │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/generic.py:11512 in sum                                                                      │
# │                                                                                                  │
# │   11509 │   │   │   min_count: int = 0,                                                          │
# │   11510 │   │   │   **kwargs,                                                                    │
# │   11511 │   │   ):                                                                               │
# │ ❱ 11512 │   │   │   return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)    │
# │   11513 │   │                                                                                    │
# │   11514 │   │   setattr(cls, "sum", sum)                                                         │
# │   11515                                                                                          │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/generic.py:11280 in sum                                                                      │
# │                                                                                                  │
# │   11277 │   │   min_count: int = 0,                                                              │
# │   11278 │   │   **kwargs,                                                                        │
# │   11279 │   ):                                                                                   │
# │ ❱ 11280 │   │   return self._min_count_stat_function(                                            │
# │   11281 │   │   │   "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs        │
# │   11282 │   │   )                                                                                │
# │   11283                                                                                          │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/generic.py:11263 in _min_count_stat_function                                                 │
# │                                                                                                  │
# │   11260 │   │   if axis is None:                                                                 │
# │   11261 │   │   │   axis = self._stat_axis_number                                                │
# │   11262 │   │                                                                                    │
# │ ❱ 11263 │   │   return self._reduce(                                                             │
# │   11264 │   │   │   func,                                                                        │
# │   11265 │   │   │   name=name,                                                                   │
# │   11266 │   │   │   axis=axis,                                                                   │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/frame.py:10524 in _reduce                                                                    │
# │                                                                                                  │
# │   10521 │   │                                                                                    │
# │   10522 │   │   # After possibly _get_data and transposing, we are now in the                    │
# │   10523 │   │   #  simple case where we can use BlockManager.reduce                              │
# │ ❱ 10524 │   │   res = df._mgr.reduce(blk_func)                                                   │
# │   10525 │   │   out = df._constructor(res).iloc[0]                                               │
# │   10526 │   │   if out_dtype is not None:                                                        │
# │   10527 │   │   │   out = out.astype(out_dtype)                                                  │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/internals/managers.py:1534 in reduce                                                         │
# │                                                                                                  │
# │   1531 │   │                                                                                     │
# │   1532 │   │   res_blocks: list[Block] = []                                                      │
# │   1533 │   │   for blk in self.blocks:                                                           │
# │ ❱ 1534 │   │   │   nbs = blk.reduce(func)                                                        │
# │   1535 │   │   │   res_blocks.extend(nbs)                                                        │
# │   1536 │   │                                                                                     │
# │   1537 │   │   index = Index([None])  # placeholder                                              │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/internals/blocks.py:339 in reduce                                                            │
# │                                                                                                  │
# │    336 │   │   #  Block with the same mgr_locs; squeezing will be done at a higher level         │
# │    337 │   │   assert self.ndim == 2                                                             │
# │    338 │   │                                                                                     │
# │ ❱  339 │   │   result = func(self.values)                                                        │
# │    340 │   │                                                                                     │
# │    341 │   │   if self.values.ndim == 1:                                                         │
# │    342 │   │   │   # TODO(EA2D): special case not needed with 2D EAs                             │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/frame.py:10487 in blk_func                                                                   │
# │                                                                                                  │
# │   10484 │   │   │   │   │   return values._reduce(name, axis=1, skipna=skipna, **kwds)           │
# │   10485 │   │   │   │   return values._reduce(name, skipna=skipna, **kwds)                       │
# │   10486 │   │   │   else:                                                                        │
# │ ❱ 10487 │   │   │   │   return op(values, axis=axis, skipna=skipna, **kwds)                      │
# │   10488 │   │                                                                                    │
# │   10489 │   │   def _get_data() -> DataFrame:                                                    │
# │   10490 │   │   │   if filter_type is None:                                                      │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/nanops.py:96 in _f                                                                           │
# │                                                                                                  │
# │     93 │   │   │   │   )                                                                         │
# │     94 │   │   │   try:                                                                          │
# │     95 │   │   │   │   with np.errstate(invalid="ignore"):                                       │
# │ ❱   96 │   │   │   │   │   return f(*args, **kwargs)                                             │
# │     97 │   │   │   except ValueError as e:                                                       │
# │     98 │   │   │   │   # we want to transform an object array                                    │
# │     99 │   │   │   │   # ValueError message to the more typical TypeError                        │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/nanops.py:421 in new_func                                                                    │
# │                                                                                                  │
# │    418 │   │   if datetimelike and mask is None:                                                 │
# │    419 │   │   │   mask = isna(values)                                                           │
# │    420 │   │                                                                                     │
# │ ❱  421 │   │   result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)              │
# │    422 │   │                                                                                     │
# │    423 │   │   if datetimelike:                                                                  │
# │    424 │   │   │   result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)            │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/nanops.py:494 in newfunc                                                                     │
# │                                                                                                  │
# │    491 │   │   │   │   results = [func(x, **kwargs) for x in arrs]                               │
# │    492 │   │   │   return np.array(results)                                                      │
# │    493 │   │                                                                                     │
# │ ❱  494 │   │   return func(values, axis=axis, **kwargs)                                          │
# │    495 │                                                                                         │
# │    496 │   return cast(F, newfunc)                                                               │
# │    497                                                                                           │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/pandas/c │
# │ ore/nanops.py:652 in nansum                                                                      │
# │                                                                                                  │
# │    649 │   elif is_timedelta64_dtype(dtype):                                                     │
# │    650 │   │   dtype_sum = np.dtype(np.float64)                                                  │
# │    651 │                                                                                         │
# │ ❱  652 │   the_sum = values.sum(axis, dtype=dtype_sum)                                           │
# │    653 │   the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)     │
# │    654 │                                                                                         │
# │    655 │   return the_sum                                                                        │
# │                                                                                                  │
# │ /home/miguel/.pyenv/versions/3.9/envs/epfl_extension_school/lib/python3.9/site-packages/numpy/co │
# │ re/_methods.py:49 in _sum                                                                        │
# │                                                                                                  │
# │    46                                                                                            │
# │    47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,                               │
# │    48 │   │    initial=_NoValue, where=True):                                                    │
# │ ❱  49 │   return umr_sum(a, axis, dtype, out, keepdims, initial, where)                          │
# │    50                                                                                            │
# │    51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,                              │
# │    52 │   │     initial=_NoValue, where=True):                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: can only concatenate str (not "int") to str

# %%
df.groupby("Musician")["Requested"].describe()
# Out:
#               count        mean         std    min     25%    50%     75%
# Musician
# Bob Dylan       3.0  210.666667   78.678671  143.0  167.50  192.0  244.50  \
# David Bowie     6.0  165.166667   32.046321  107.0  156.25  177.5  183.75
# Led Zeppelin   11.0  234.818182  124.607237   65.0  136.50  220.0  319.50
#
#                 max
# Musician
# Bob Dylan     297.0
# David Bowie   194.0
# Led Zeppelin  435.0

# %%
df.groupby("Musician")["Decade"].agg(
    lambda x: str(min(x)) + "-" + str(max(x))
).to_frame()
# Out:
#              Decade
# Musician
# Bob Dylan     60-70
# David Bowie   60-90
# Led Zeppelin  60-70

# %%
grouped_df = df.groupby("Musician").agg(
    {
        "Name": "count",
        "Decade": lambda x: str(min(x)) + "-" + str(max(x)),
        "Requested": ["sum", "max", np.mean],
    }
)

# Renaming some columns
grouped_df.rename(columns={"count": "Total", "<lambda>": "span"})
# Out:
#               Name Decade Requested
#              Total   span       sum  max        mean
# Musician
# Bob Dylan        3  60-70       632  297  210.666667
# David Bowie      6  60-90       991  194  165.166667
# Led Zeppelin    11  60-70      2583  435  234.818182
